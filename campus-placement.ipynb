# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('datasets_596958_1073629_Placement_Data_Full_Class.csv')

# %%
df.head(5)
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.gender.head(5)
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# Name: gender, dtype: object

# %%
sns.pairplot(df, kind="reg")
plt.show()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /usr/local/anaconda3/lib/python3.7/site-packages/numpy/lib/histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
# sl_no             215 non-null int64
# gender            215 non-null object
# ssc_p             215 non-null float64
# ssc_b             215 non-null object
# hsc_p             215 non-null float64
# hsc_b             215 non-null object
# hsc_s             215 non-null object
# degree_p          215 non-null float64
# degree_t          215 non-null object
# workex            215 non-null object
# etest_p           215 non-null float64
# specialisation    215 non-null object
# mba_p             215 non-null float64
# status            215 non-null object
# salary            148 non-null float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df[df.gender == 'M']
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 209    210      M  62.00  Central  72.00  Central  Commerce     65.00
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# 0     Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1     Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2    Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3     Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4    Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
# ..         ...    ...      ...            ...    ...         ...       ...
# 209  Comm&Mgmt     No     67.0        Mkt&Fin  56.49      Placed  216000.0
# 210  Comm&Mgmt     No     91.0        Mkt&Fin  74.49      Placed  400000.0
# 211   Sci&Tech     No     74.0        Mkt&Fin  53.62      Placed  275000.0
# 212  Comm&Mgmt    Yes     59.0        Mkt&Fin  69.72      Placed  295000.0
# 214  Comm&Mgmt     No     89.0         Mkt&HR  60.22  Not Placed       NaN
#
# [139 rows x 15 columns]

# %%
df[df.hsc_s == 'Arts']
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b hsc_s  degree_p   degree_t  \
# 2        3      M   65.0  Central   68.0  Central  Arts     64.00  Comm&Mgmt
# 19      20      M   60.0   Others   67.0   Others  Arts     70.00  Comm&Mgmt
# 49      50      F   50.0   Others   37.0   Others  Arts     52.00     Others
# 76      77      F   66.5   Others   70.4  Central  Arts     71.93  Comm&Mgmt
# 122    123      F   66.5  Central   66.8  Central  Arts     69.30  Comm&Mgmt
# 136    137      F   47.0  Central   59.0  Central  Arts     64.00  Comm&Mgmt
# 144    145      M   52.0   Others   50.0   Others  Arts     61.00  Comm&Mgmt
# 148    149      F   77.0  Central   86.0  Central  Arts     56.00     Others
# 149    150      M   44.0  Central   58.0  Central  Arts     55.00  Comm&Mgmt
# 182    183      M   52.0   Others   65.0   Others  Arts     57.00     Others
# 193    194      F   60.0  Central   63.0  Central  Arts     56.00     Others
#
#     workex  etest_p specialisation  mba_p      status    salary
# 2       No    75.00        Mkt&Fin  57.80      Placed  250000.0
# 19     Yes    50.48        Mkt&Fin  77.89      Placed  236000.0
# 49      No    65.00         Mkt&HR  56.11  Not Placed       NaN
# 76      No    61.00        Mkt&Fin  64.27      Placed  230000.0
# 122    Yes    80.40        Mkt&Fin  71.00      Placed  236000.0
# 136     No    78.00        Mkt&Fin  61.58  Not Placed       NaN
# 144     No    60.00        Mkt&Fin  58.52  Not Placed       NaN
# 148     No    57.00        Mkt&Fin  64.08      Placed  240000.0
# 149    Yes    64.25         Mkt&HR  58.54  Not Placed       NaN
# 182    Yes    75.00        Mkt&Fin  59.81  Not Placed       NaN
# 193    Yes    80.00         Mkt&HR  56.63      Placed  300000.0
